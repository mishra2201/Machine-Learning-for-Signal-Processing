# %% [markdown]
# <b> Question: </b> Momentum <br>Aren't $ \beta $ and $ \alpha $ effectively scaling the same thing?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <i> Well, $ \alpha $ (learning rate) scales the net momentum. Can follow scheduler in SDG such that rate is smaller in later training sets. $ \beta $ contrains relation between momentum and gradient. I.e. $ \alpha $ would "smooth" each factor equally versus $ \beta $ will weigh the relation between the two.
